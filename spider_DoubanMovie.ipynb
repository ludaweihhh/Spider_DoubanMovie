# %%
import requests
from bs4 import BeautifulSoup
import xlwt


def request_douban(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
    except requests.RequestException:
        return None


book = xlwt.Workbook(encoding='utf-8', style_compression=0)

sheet = book.add_sheet('豆瓣电影Top250', cell_overwrite_ok=True)
sheet.write(0, 0, '名称')
sheet.write(0, 1, '图片')
sheet.write(0, 2, '排名')
sheet.write(0, 3, '评分')
sheet.write(0, 4, '作者')
sheet.write(0, 5, '简介')

n = 1


def save_to_excel(soup):
    list = soup.find(class_='grid_view').find_all('li')

    for item in list:
        item_name = item.find(class_='title').string
        item_img = item.find('a').find('img').get('src')
        item_index = item.find(class_='').string
        item_score = item.find(class_='rating_num').string
        item_author = item.find('p').text
        
        if (item.find(class_='inq') != None):
            item_intr = item.find(class_='inq').string
        else:
            item_intr = item.find(class_='title').string

        # print('爬取电影：' + item_index + ' | ' + item_name +' | ' + item_img +' | ' + item_score +' | ' + item_author +' | ' + item_intr )
        print('爬取电影：' + item_index + ' | ' + item_name + ' | ' + item_score + ' | ' + item_intr)

        global n

        sheet.write(n, 0, item_name)
        sheet.write(n, 1, item_img)
        sheet.write(n, 2, item_index)
        sheet.write(n, 3, item_score)
        sheet.write(n, 4, item_author)
        sheet.write(n, 5, item_intr)

        n = n + 1


def main(page):
    url = 'https://movie.douban.com/top250?start=' + str(page * 25) + '&filter='
    html = request_douban(url)
    soup = BeautifulSoup(html, 'lxml')
    save_to_excel(soup)


if __name__ == '__main__':

    for i in range(1, 10):
        main(i)

book.save(u'豆瓣最受欢迎的250部电影.xlsx')
# Out:
# 爬取电影：26 | 蝙蝠侠：黑暗骑士 | 9.1 | 无尽的黑暗。
# 爬取电影：27 | 乱世佳人 | 9.3 | Tomorrow is another day.
# 爬取电影：28 | 活着 | 9.2 | 张艺谋最好的电影。
# 爬取电影：29 | 控方证人 | 9.6 | 比利·怀德满分作品。
# 爬取电影：30 | 少年派的奇幻漂流 | 9.0 | 瑰丽壮观、无人能及的冒险之旅。
# 爬取电影：31 | 摔跤吧！爸爸 | 9.0 | 你不是在为你一个人战斗，你要让千千万万的女性看到女生并不是只能相夫教子。
# 爬取电影：32 | 指环王3：王者无敌 | 9.2 | 史诗的终章。
# 爬取电影：33 | 天空之城 | 9.1 | 对天空的追逐，永不停止。
# 爬取电影：34 | 鬼子来了 | 9.2 | 对敌人的仁慈，就是对自己残忍。
# 爬取电影：35 | 十二怒汉 | 9.4 | 1957年的理想主义。
# 爬取电影：36 | 天堂电影院 | 9.2 | 那些吻戏，那些青春，都在影院的黑暗里被泪水冲刷得无比清晰。
# 爬取电影：37 | 飞屋环游记 | 9.0 | 最后那些最无聊的事情，才是最值得怀念的。
# 爬取电影：38 | 大话西游之月光宝盒 | 9.0 | 旷古烁今。
# 爬取电影：39 | 哈尔的移动城堡 | 9.0 | 带着心爱的人在天空飞翔。
# 爬取电影：40 | 罗马假日 | 9.0 | 爱情哪怕只有一天。
# 爬取电影：41 | 搏击俱乐部 | 9.0 | 邪恶与平庸蛰伏于同一个母体，在特定的时间互相对峙。
# 爬取电影：42 | 末代皇帝 | 9.2 | “不要跟我比惨，我比你更惨”再适合这部电影不过了。
# 爬取电影：43 | 寻梦环游记 | 9.0 | 死亡不是真的逝去，遗忘才是永恒的消亡。
# 爬取电影：44 | 闻香识女人 | 9.0 | 史上最美的探戈。
# 爬取电影：45 | 辩护人 | 9.2 | 电影的现实意义大过电影本身。
# 爬取电影：46 | 素媛 | 9.2 | 受过伤害的人总是笑得最开心，因为他们不愿意让身边的人承受一样的痛苦。
# 爬取电影：47 | 窃听风暴 | 9.1 | 别样人生。
# 爬取电影：48 | 死亡诗社 | 9.0 | 当一个死水般的体制内出现一个活跃的变数时，所有的腐臭都站在了光明的对面。
# 爬取电影：49 | 两杆大烟枪 | 9.1 | 4个臭皮匠顶个诸葛亮，盖·里奇果然不是盖的。
# 爬取电影：50 | 飞越疯人院 | 9.1 | 自由万岁。
# 爬取电影：51 | 指环王2：双塔奇兵 | 9.0 | 承前启后的史诗篇章。
# 爬取电影：52 | 教父2 | 9.2 | 优雅的孤独。
# 爬取电影：53 | 狮子王 | 9.0 | 动物版《哈姆雷特》。
# 爬取电影：54 | 指环王1：魔戒再现 | 9.0 | 传说的开始。
# 爬取电影：55 | V字仇杀队 | 8.9 | 一张面具背后的理想与革命。
# 爬取电影：56 | 美丽心灵 | 9.0 | 爱是一切逻辑和原由。
# 爬取电影：57 | 饮食男女 | 9.1 | 人生不能像做菜，把所有的料都准备好了才下锅。
# 爬取电影：58 | 何以为家 | 9.1 | 凝视卑弱生命，用电影改变命运。
# 爬取电影：59 | 海豚湾 | 9.3 | 海豚的微笑，是世界上最高明的伪装。
# 爬取电影：60 | 情书 | 8.9 | 暗恋的极致。
# 爬取电影：61 | 大闹天宫 | 9.3 | 经典之作，历久弥新。
# 爬取电影：62 | 钢琴家 | 9.1 | 音乐能化解仇恨。
# 爬取电影：63 | 哈利·波特与魔法石 | 8.9 | 童话世界的开端。
# 爬取电影：64 | 本杰明·巴顿奇事 | 8.9 | 在时间之河里感受溺水之苦。
# 爬取电影：65 | 看不见的客人 | 8.8 | 你以为你以为的就是你以为的。
# 爬取电影：66 | 黑客帝国 | 8.9 | 视觉革命。
# 爬取电影：67 | 西西里的美丽传说 | 8.8 | 美丽无罪。
# 爬取电影：68 | 小鞋子 | 9.2 | 奔跑的孩子是天使。
# 爬取电影：69 | 让子弹飞 | 8.8 | 你给我翻译翻译，神马叫做TMD的惊喜。
# 爬取电影：70 | 美国往事 | 9.2 | 往事如烟，无处祭奠。
# 爬取电影：71 | 拯救大兵瑞恩 | 9.0 | 美利坚精神输出大片No1.
# 爬取电影：72 | 音乐之声 | 9.0 | 用音乐化解仇恨，让歌声串起美好。
# 爬取电影：73 | 猫鼠游戏 | 8.9 | 骗子大师和执著警探的你追我跑故事。
# 爬取电影：74 | 致命魔术 | 8.8 | 孪生蝙蝠侠大战克隆金刚狼。
# 爬取电影：75 | 七宗罪 | 8.8 | 警察抓小偷，老鼠玩死猫。
# 爬取电影：76 | 被嫌弃的松子的一生 | 8.9 | 以戏谑来戏谑戏谑。
# 爬取电影：77 | 低俗小说 | 8.8 | 故事的高级讲法。
# 爬取电影：78 | 沉默的羔羊 | 8.8 | 安东尼·霍普金斯的顶级表演。
# 爬取电影：79 | 蝴蝶效应 | 8.8 | 人的命运被自己瞬间的抉择改变。
# 爬取电影：80 | 春光乍泄 | 8.9 | 爱情纠缠，男女一致。
# 爬取电影：81 | 穿条纹睡衣的男孩 | 9.0 | 尽管有些不切实际的幻想，这部电影依旧是一部感人肺腑的佳作。
# 爬取电影：82 | 勇敢的心 | 8.9 | 史诗大片的典范。
# 爬取电影：83 | 天使爱美丽 | 8.7 | 法式小清新。
# 爬取电影：84 | 剪刀手爱德华 | 8.7 | 浪漫忧郁的成人童话。
# 爬取电影：85 | 心灵捕手 | 8.8 | 人生中应该拥有这样的一段豁然开朗。
# 爬取电影：86 | 禁闭岛 | 8.8 | 昔日翩翩少年，今日大腹便便。
# 爬取电影：87 | 布达佩斯大饭店 | 8.8 | 小清新的故事里注入了大历史的情怀。
# 爬取电影：88 | 阿凡达 | 8.7 | 绝对意义上的美轮美奂。
# 爬取电影：89 | 入殓师 | 8.8 | 死可能是一道门，逝去并不是终结，而是超越，走向下一程。
# 爬取电影：90 | 幽灵公主 | 8.9 | 人与自然的战争史诗。
# 爬取电影：91 | 加勒比海盗 | 8.7 | 约翰尼·德普的独角戏。
# 爬取电影：92 | 摩登时代 | 9.3 | 大时代中的人生，小人物的悲喜。
# 爬取电影：93 | 致命ID | 8.7 | 最不可能的那个人永远是最可能的。
# 爬取电影：94 | 断背山 | 8.7 | 每个人心中都有一座断背山。
# 爬取电影：95 | 阳光灿烂的日子 | 8.8 | 一场华丽的意淫。
# 爬取电影：96 | 重庆森林 | 8.7 | 寂寞没有期限。
# 爬取电影：97 | 第六感 | 8.8 | 深入内心的恐怖，出人意料的结局。
# 爬取电影：98 | 狩猎 | 9.1 | 人言可畏。
# 爬取电影：99 | 喜剧之王 | 8.7 | 我是一个演员。
# 爬取电影：100 | 玛丽和马克思 | 8.9 | 你是我最好的朋友，你是我唯一的朋友 。
# 爬取电影：101 | 我不是药神 | 9.0 | 我不是药神
# 爬取电影：102 | 消失的爱人 | 8.7 | 年度最佳date movie。
# 爬取电影：103 | 告白 | 8.7 | 没有一人完全善，也没有一人完全恶。
# 爬取电影：104 | 小森林 夏秋篇 | 9.0 | 那些静得只能听见呼吸的日子里，你明白孤独即生活。
# 爬取电影：105 | 大鱼 | 8.8 | 抱着梦想而活着的人是幸福的，怀抱梦想而死去的人是不朽的。
# 爬取电影：106 | 一一 | 9.0 | 我们都曾经是一一。
# 爬取电影：107 | 请以你的名字呼唤我 | 8.8 | 沉醉在电影的情感和视听氛围中无法自拔。
# 爬取电影：108 | 阳光姐妹淘 | 8.8 | 再多各自牛逼的时光，也比不上一起傻逼的岁月。
# 爬取电影：109 | 爱在黎明破晓前 | 8.8 | 缘分是个连绵词，最美不过一瞬。
# 爬取电影：110 | 射雕英雄传之东成西就 | 8.7 | 百看不厌。
# 爬取电影：111 | 侧耳倾听 | 8.9 | 少女情怀总是诗。
# 爬取电影：112 | 甜蜜蜜 | 8.8 | 相逢只要一瞬间，等待却像是一辈子。
# 爬取电影：113 | 红辣椒 | 9.0 | 梦的勾结。
# 爬取电影：114 | 海蒂和爷爷 | 9.1 | 如果生活中有什么使你感到快乐，那就去做吧！不要管别人说什么。
# 爬取电影：115 | 驯龙高手 | 8.7 | 和谐的生活离不开摸头与被摸头。
# 爬取电影：116 | 杀人回忆 | 8.8 | 关于连环杀人悬案的集体回忆。
# 爬取电影：117 | 倩女幽魂 | 8.7 | 两张绝世的脸。
# 爬取电影：118 | 超脱 | 8.8 | 穷尽一生，我们要学会的，不过是彼此拥抱。
# 爬取电影：119 | 7号房的礼物 | 8.8 | 《我是山姆》的《美丽人生》。
# 爬取电影：120 | 恐怖直播 | 8.8 | 恐怖分子的“秋菊打官司”。
# 爬取电影：121 | 菊次郎的夏天 | 8.8 | 从没见过那么流氓的温柔，从没见过那么温柔的流氓。
# 爬取电影：122 | 哈利·波特与死亡圣器(下) | 8.7 | 10年的完美句点。
# 爬取电影：123 | 小森林 冬春篇 | 9.0 | 尊敬他人，尊敬你生活的这片土地，明白孤独是人生的常态。
# 爬取电影：124 | 爱在日落黄昏时 | 8.8 | 九年后的重逢是世俗和责任的交叠，没了悸动和青涩，沧桑而温暖。
# 爬取电影：125 | 风之谷 | 8.8 | 动画片的圣经。
# 爬取电影：126 | 幸福终点站 | 8.7 | 有时候幸福需要等一等。
# 爬取电影：127 | 蝙蝠侠：黑暗骑士崛起 | 8.7 | 诺兰就是保证。
# 爬取电影：128 | 萤火之森 | 8.8 | 触不到的恋人。
# 爬取电影：129 | 上帝之城 | 8.9 | 被上帝抛弃了的上帝之城。
# 爬取电影：130 | 唐伯虎点秋香 | 8.6 | 华太师是黄霑，吴镇宇四大才子之一。
# 爬取电影：131 | 借东西的小人阿莉埃蒂 | 8.8 | 曾经的那段美好会沉淀为一辈子的记忆。
# 爬取电影：132 | 超能陆战队 | 8.6 | Balalala~~~
# 爬取电影：133 | 神偷奶爸 | 8.6 | Mr. I Don't Care其实也有Care的时候。
# 爬取电影：134 | 无人知晓 | 9.1 | 我的平常生活就是他人的幸福。
# 爬取电影：135 | 怪兽电力公司 | 8.7 | 不要给它起名字，起了名字就有感情了。
# 爬取电影：136 | 电锯惊魂 | 8.7 | 真相就在眼前。
# 爬取电影：137 | 玩具总动员3 | 8.8 | 跨度十五年的欢乐与泪水。
# 爬取电影：138 | 岁月神偷 | 8.7 | 岁月流逝，来日可追。
# 爬取电影：139 | 血战钢锯岭 | 8.7 | 优秀的战争片不会美化战场，不会粉饰死亡，不会矮化敌人，不会无视常识，最重要的，不会宣扬战争。
# 爬取电影：140 | 谍影重重3 | 8.8 | 像吃了苏打饼一样干脆的电影。
# 爬取电影：141 | 疯狂原始人 | 8.7 | 老少皆宜，这就是好莱坞动画的魅力。
# 爬取电影：142 | 英雄本色 | 8.7 | 英雄泪短，兄弟情长。
# 爬取电影：143 | 喜宴 | 8.9 | 中国家庭的喜怒哀乐忍。
# 爬取电影：144 | 七武士 | 9.2 | 时代悲歌。
# 爬取电影：145 | 萤火虫之墓 | 8.7 | 幸福是生生不息，却难以触及的远。
# 爬取电影：146 | 东邪西毒 | 8.6 | 电影诗。
# 爬取电影：147 | 傲慢与偏见 | 8.6 | 爱是摈弃傲慢与偏见之后的曙光。
# 爬取电影：148 | 真爱至上 | 8.6 | 爱，是个动词。
# 爬取电影：149 | 时空恋旅人 | 8.7 | 把每天当作最后一天般珍惜度过，积极拥抱生活，就是幸福。
# 爬取电影：150 | 贫民窟的百万富翁 | 8.6 | 上帝之城+猜火车+阿甘正传+开心辞典=山寨富翁
# 爬取电影：151 | 黑天鹅 | 8.5 | 黑暗之美。
# 爬取电影：152 | 记忆碎片 | 8.6 | 一个针管引发的血案。
# 爬取电影：153 | 心迷宫 | 8.7 | 荒诞讽刺，千奇百巧，抽丝剥茧，百转千回。
# 爬取电影：154 | 纵横四海 | 8.8 | 香港浪漫主义警匪动作片的巅峰之作。
# 爬取电影：155 | 教父3 | 8.8 | 任何信念的力量，都无法改变命运。
# 爬取电影：156 | 荒蛮故事 | 8.8 | 始于荒诞，止于更荒诞。
# 爬取电影：157 | 完美的世界 | 9.1 | 坏人的好总是比好人的好来得更感人。
# 爬取电影：158 | 达拉斯买家俱乐部 | 8.7 | Jared Leto的腿比女人还美！
# 爬取电影：159 | 三块广告牌 | 8.7 | 怼天怼地，你走后，她与世界为敌。
# 爬取电影：160 | 雨人 | 8.7 | 生活在自己的世界里，也可以让周围的人显得可笑和渺小。
# 爬取电影：161 | 被解救的姜戈 | 8.7 | 热血沸腾，那个低俗、性感的无耻混蛋又来了。
# 爬取电影：162 | 花样年华 | 8.6 | 偷情本没有这样美。
# 爬取电影：163 | 卢旺达饭店 | 8.9 | 当这个世界闭上双眼，他却敞开了怀抱。
# 爬取电影：164 | 你的名字。 | 8.4 | 穿越错位的时空，仰望陨落的星辰，你没留下你的名字，我却无法忘记那句“我爱你”。
# 爬取电影：165 | 我是山姆 | 8.9 | 爱并不需要智商 。
# 爬取电影：166 | 哪吒闹海 | 9.0 | 想你时你在闹海。
# 爬取电影：167 | 头脑特工队 | 8.7 | 愿我们都不用长大，每一座城堡都能永远存在。
# 爬取电影：168 | 海边的曼彻斯特 | 8.6 | 我们都有权利不与自己的过去和解。
# 爬取电影：169 | 你看起来好像很好吃 | 8.8 | 感情不分食草或者食肉。
# 爬取电影：170 | 恋恋笔记本 | 8.5 | 爱情没有那么多借口，如果不能圆满，只能说明爱的不够。
# 爬取电影：171 | 无敌破坏王 | 8.7 | 迪士尼和皮克斯拿错剧本的产物。
# 爬取电影：172 | 冰川时代 | 8.5 | 松鼠才是角儿。
# 爬取电影：173 | 二十二 | 8.7 | 有一些东西不应该被遗忘。
# 爬取电影：174 | 虎口脱险 | 8.9 | 永远看不腻的喜剧。
# 爬取电影：175 | 未麻的部屋 | 8.9 | 好的剧本是，就算你猜到了结局也猜不到全部。
# 爬取电影：176 | 海洋 | 9.1 | 大海啊，不全是水。
# 爬取电影：177 | 模仿游戏 | 8.6 | 他给机器起名“克里斯托弗”，因为这是他初恋的名字。
# 爬取电影：178 | 爆裂鼓手 | 8.7 | 这个世界从不善待努力的人，努力了也不一定会成功，但是知道自己在努力，就是活下去的动力。
# 爬取电影：179 | 雨中曲 | 9.0 | 骨灰级歌舞片。
# 爬取电影：180 | 一个叫欧维的男人决定去死 | 8.8 | 惠及一生的美丽。
# 爬取电影：181 | 忠犬八公物语 | 9.1 | 养狗三日，便会对你终其一生。
# 爬取电影：182 | 燃情岁月 | 8.8 | 传奇，不是每个人都可以拥有。
# 爬取电影：183 | 人工智能 | 8.6 | 对爱的执着，可以超越一切。
# 爬取电影：184 | 天书奇谭 | 9.2 | 传奇的年代，醉人的童话。
# 爬取电影：185 | 魔女宅急便 | 8.6 | 宫崎骏的电影总让人感觉世界是美好的，阳光明媚的。
# 爬取电影：186 | 房间 | 8.8 | 被偷走的岁月，被伤害的生命，被禁锢的灵魂，终将被希望和善意救赎。
# 爬取电影：187 | 穿越时空的少女 | 8.6 | 爱上未来的你。
# 爬取电影：188 | 黑客帝国3：矩阵革命 | 8.7 | 不得不说，《黑客帝国》系列是商业片与科幻、哲学完美结合的典范。
# 爬取电影：189 | 恐怖游轮 | 8.4 | 不要企图在重复中寻找已经失去的爱。
# 爬取电影：190 | 海街日记 | 8.7 | 是枝裕和的家庭习作。
# 爬取电影：191 | 魂断蓝桥 | 8.8 | 中国式内在的美国电影。
# 爬取电影：192 | 头号玩家 | 8.7 | 写给影迷，动漫迷和游戏迷的一封情书。
# 爬取电影：193 | 猜火车 | 8.5 | 不可猜的青春迷笛。
# 爬取电影：194 | 完美陌生人 | 8.5 | 来啊，互相伤害啊！
# 爬取电影：195 | 罗生门 | 8.8 | 人生的N种可能性。
# 爬取电影：196 | 惊魂记 | 8.9 | 故事的反转与反转，分裂电影的始祖。
# 爬取电影：197 | 功夫 | 8.4 | 警恶惩奸，维护世界和平这个任务就交给你了，好吗？
# 爬取电影：198 | 阿飞正传 | 8.5 | 王家卫是一种风格，张国荣是一个代表。
# 爬取电影：199 | 香水 | 8.5 | 一个单凭体香达到高潮的男人。
# 爬取电影：200 | 可可西里 | 8.7 | 坚硬的信仰。
# 爬取电影：201 | 谍影重重2 | 8.6 | 谁说王家卫镜头很晃？
# 爬取电影：202 | 牯岭街少年杀人事件 | 8.8 | 弱者送给弱者的一刀。
# 爬取电影：203 | 朗读者 | 8.5 | 当爱情跨越年龄的界限，它似乎能变得更久远一点，成为一种责任，一种水到渠成的相濡以沫。
# 爬取电影：204 | 浪潮 | 8.7 | 世界离独裁只有五天。
# 爬取电影：205 | 谍影重重 | 8.6 | 哗啦啦啦啦，天在下雨，哗啦啦啦啦，云在哭泣……找自己。
# 爬取电影：206 | 疯狂的石头 | 8.4 | 中国版《两杆大烟枪》。
# 爬取电影：207 | 战争之王 | 8.6 | 做一颗让别人需要你的棋子。
# 爬取电影：208 | 地球上的星星 | 8.9 | 天使保护事件始末。
# 爬取电影：209 | 初恋这件小事 | 8.3 | 黑小鸭速效美白记。
# 爬取电影：210 | 青蛇 | 8.5 | 人生如此，浮生如斯。谁人言，花彼岸，此生情长意短。谁都是不懂爱的罢了。
# 爬取电影：211 | 终结者2：审判日 | 8.6 | 少见的超越首部的续集，动作片中的经典。
# 爬取电影：212 | 奇迹男孩 | 8.6 | 世界不完美，爱会有奇迹。
# 爬取电影：213 | 爱在午夜降临前 | 8.8 | 所谓爱情，就是话唠一路，都不会心生腻烦，彼此嫌弃。
# 爬取电影：214 | 源代码 | 8.4 | 邓肯·琼斯继《月球》之后再度奉献出一部精彩绝伦的科幻佳作。
# 爬取电影：215 | 新龙门客栈 | 8.5 | 嬉笑怒骂，调风动月。
# 爬取电影：216 | 步履不停 | 8.8 | 日本的家庭电影已经是世界巅峰了，步履不停是巅峰中的佳作。
# 爬取电影：217 | 小萝莉的猴神大叔 | 8.5 | 宝莱坞的萝莉与大叔。
# 爬取电影：218 | 无耻混蛋 | 8.5 | 昆汀同学越来越变态了，比北野武还杜琪峰。
# 爬取电影：219 | 釜山行 | 8.4 | 揭露人性的丧尸题材力作。
# 爬取电影：220 | 再次出发之纽约遇见你 | 8.5 | 爱我就给我看你的播放列表。
# 爬取电影：221 | 一次别离 | 8.7 | 只有有信仰的人才能说出事实真相。
# 爬取电影：222 | 追随 | 8.9 | 诺兰的牛逼来源于内心散发出的恐惧。
# 爬取电影：223 | 新世界 | 8.7 | 要做就做得狠一点，这样才能活下去。
# 爬取电影：224 | 血钻 | 8.6 | 每个美丽事物背后都是滴血的现实。
# 爬取电影：225 | 彗星来的那一夜 | 8.5 | 小成本大魅力。
# 爬取电影：226 | 2001太空漫游 | 8.7 | 现代科幻电影的开山之作，最伟大导演的最伟大影片。
# 爬取电影：227 | 城市之光 | 9.3 | 永远的小人物，伟大的卓别林。
# 爬取电影：228 | 东京物语 | 9.2 | 东京那么大，如果有一天走失了，恐怕一辈子不能再相见。
# 爬取电影：229 | 绿里奇迹 | 8.7 | 天使暂时离开。
# 爬取电影：230 | 撞车 | 8.6 | 天使与魔鬼的冲撞。
# 爬取电影：231 | 梦之安魂曲 | 8.7 | 一场没有春天的噩梦。
# 爬取电影：232 | 疯狂的麦克斯4：狂暴之路 | 8.6 | “多么美好的一天！”轰轰轰砰咚，啪哒哒哒轰隆隆，磅~
# 爬取电影：233 | 聚焦 | 8.8 | 新闻人的理性求真。
# 爬取电影：234 | E.T. 外星人 | 8.6 | 生病的E.T.皮肤的颜色就像柿子饼。
# 爬取电影：235 | 黑鹰坠落 | 8.6 | 还原真实而残酷的战争。
# 爬取电影：236 | 这个男人来自地球 | 8.5 | 科幻真正的魅力不是视觉效果能取代的。
# 爬取电影：237 | 末路狂花 | 8.7 | 没有了退路，只好飞向自由。
# 爬取电影：238 | 遗愿清单 | 8.6 | 用剩余不多的时间，去燃烧整个生命。
# 爬取电影：239 | 发条橙 | 8.5 | 我完全康复了。
# 爬取电影：240 | 变脸 | 8.4 | 当发哥的风衣、墨镜出现在了凯奇身上⋯⋯
# 爬取电影：241 | 国王的演讲 | 8.4 | 皇上无话儿。
# 爬取电影：242 | 我爱你 | 9.0 | 你要相信，这世上真的有爱存在，不管在什么年纪
# 爬取电影：243 | 勇闯夺命岛 | 8.6 | 类型片的极致。
# 爬取电影：244 | 千钧一发 | 8.7 | 一部能引人思考的科幻励志片。
# 爬取电影：245 | 哈利·波特与密室 | 8.4 | 魔法的密室之门已打开...
# 爬取电影：246 | 哈利·波特与阿兹卡班的囚徒 | 8.5 | 哈利·波特与阿兹卡班的囚徒
# 爬取电影：247 | 黄金三镖客 | 9.1 | 最棒的西部片。
# 爬取电影：248 | 非常嫌疑犯 | 8.6 | 我不信仰上帝，但我敬畏上帝。
# 爬取电影：249 | 驴得水 | 8.3 | 过去的如果就让它过去了，未来只会越来越糟！
# 爬取电影：250 | 秒速5厘米 | 8.3 | 青春就是放弃和怀念。
